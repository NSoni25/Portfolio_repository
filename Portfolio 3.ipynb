# %% [markdown]
# ## Predicting the Genre of Books from Summaries
#
# This portfolio is all about predicting the genre tag of book by building a model that will depict the genre tags from summary.We'll use a set of book summaries from the [CMU Book Summaries Corpus](http://www.cs.cmu.edu/~dbamman/booksummaries.html) in this experiment.  This contains a large number of summaries (16,559) and includes meta-data about the genre of the books taken from Freebase.  Each book can have more than one genre and there are 227 genres listed in total.  To simplify the problem of genre prediction we will select a small number of target genres that occur frequently in the collection and select the books with these genre labels.  This will give us one genre label per book.
#
# Our goal in this portfolio is to take this data and build a predictive model to classify the books into one of the five target genres.  We will extract suitable features from the summary and build a suitable model to predict the genre the of the book

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
import nltk
from nltk.corpus import stopwords
stop_words=stopwords.words('english')
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
# %matplotlib inline
import re

# %% [markdown]
# ## Data Preparation
#
# Our first task is to read the data. It is made available in tab-separated format with no column names. We will use `read_csv` to read the data and used '\t' (tab)  separator to  and supply the column names.  The field names we get  from the [ReadMe](data/booksummaries/README.txt) file.

# %%
names = ['wid', 'fid', 'title', 'author', 'date', 'genres', 'summary']

books = pd.read_csv("data/booksummaries/booksummaries.txt", sep="\t", header=None, names=names, keep_default_na=False)
books.head()
# Out:
#     wid      fid                                      title           author  \
# 0   620  /m/0hhy                                Animal Farm    George Orwell
# 1   843  /m/0k36                         A Clockwork Orange  Anthony Burgess
# 2   986  /m/0ldx                                 The Plague     Albert Camus
# 3  1756  /m/0sww  An Enquiry Concerning Human Understanding       David Hume
# 4  2080  /m/0wkt                       A Fire Upon the Deep     Vernor Vinge
#
#          date                                             genres  \
# 0  1945-08-17  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1        1962  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2        1947  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3
# 4              {"/m/03lrw": "Hard science fiction", "/m/06n90...
#
#                                              summary
# 0   Old Major, the old boar on the Manor Farm, ca...
# 1   Alex, a teenager living in near-future Englan...
# 2   The text of The Plague is divided into five p...
# 3   The argument of the Enquiry proceeds by a ser...
# 4   The novel posits that space around the Milky ...

# %% [markdown]
# We next filter the data so that only our target genre labels are included and we assign each text to just one of the genre labels.  It's possible that one text could be labelled with two of these labels (eg. Science Fiction and Fantasy) but we will just assign one of those here.

# %%
target_genres = ["Children's literature",
                 'Science Fiction',
                 'Novel',
                 'Fantasy',
                 'Mystery']

# create a Series of empty strings the same length as the list of books
genre = pd.Series(np.repeat("", books.shape[0]))
# look for each target genre and set the corresponding entries in the genre series to the genre label
for g in target_genres:
    genre[books['genres'].str.contains(g)] = g

# add this to the book dataframe and then select only those rows that have a genre label
# drop some useless columns
books['genre'] = genre
genre_books = books[genre!=''].drop(['genres', 'fid', 'wid'], axis=1)

genre_books.shape
# Out:
# (8954, 5)

# %%
# check how many books we have in each genre category
genre_books.groupby('genre').count()
# Out:
#                        title  author  date  summary
# genre
# Children's literature   1092    1092  1092     1092
# Fantasy                 2311    2311  2311     2311
# Mystery                 1396    1396  1396     1396
# Novel                   2258    2258  2258     2258
# Science Fiction         1897    1897  1897     1897

# %% [markdown]
# ## Modelling

# %%
#Find the unique genre in the genre_books
print("Unique genre in the books:",genre_books['genre'].unique())
# Out:
# Unique genre in the books: ["Children's literature" 'Novel' 'Fantasy' 'Science Fiction' 'Mystery']

# %% [markdown]
# Our First task is to clean the data and the target features by removing numerical characters and special characters from the list.After cleaning the summary data, we will remove stopwords from the summary columns  and store the clean the data in a column of the genre_book dataframe.

# %%
#Clean the genres in the dataset
genres=[]
import re
for i in genre_books['genre']:
    genres.append(re.sub("'","",i))
genre_books['genre']=genres

# %%
print("Clean and unique genre in the books:",genre_books['genre'].unique())
# Out:
# Clean and unique genre in the books: ['Childrens literature' 'Novel' 'Fantasy' 'Science Fiction' 'Mystery']

# %%
#clean the text and remove stopwords from the summary columns
def Clean_text(text):
    text=re.sub("[^a-zA-Z]"," ",text)
    text = ' '.join(text.split())
    text=text.lower()
    text=(item for item in text.split() if item not in stop_words)
    return ' '.join(text)

# %%
genre_books['summary'] = genre_books['summary'].apply(lambda x: Clean_text(x))

# %% [markdown]
# Now, we will start our building our model by converting the genre into the features.Since we have single column data so we will
# use LabelBinarizer that will convert the text genre into the features.LabelBinarizer makes our process easy by using the transform method.

# %%
lb = preprocessing.LabelBinarizer()
lb.fit(genre_books['genre'])

# transform target variable into feature
y = lb.transform(genre_books['genre'])

# %% [markdown]
# After that we will use TfidfVectorizer that computes the word counts, IDF values, and Tf-idf scores all in one step in the  same dataset.In the TfidfVectorizer, we have use max_df=0.8, it will remove those words that appears more than in 80% in the document and use 10000 most frequent words as a feature in our model

# %%
tfidf_vector = TfidfVectorizer(max_df=0.8, max_features=10000)

# %% [markdown]
# Next, we will split the columns summary and genre into test and train dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(genre_books['summary'], y, test_size=0.25, random_state=142)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((6715,), (2239,), (6715, 5), (2239, 5))

# %% [markdown]
# Next we will use tfidf_vectorization to calculate the tf-idf of X_train and X_test dataset

# %%
Xtrain_tfidf = tfidf_vector.fit_transform(X_train)
Xtest_tfidf= tfidf_vector.transform(X_test)
print("TF_IDF for Train data set of summary:", Xtrain_tfidf.shape)
print("TF_IDF for Test data set of summary:", Xtest_tfidf.shape)
# Out:
# TF_IDF for Train data set of summary: (6715, 10000)
# TF_IDF for Test data set of summary: (2239, 10000)

# %% [markdown]
# Since we have 5 different target variables so we will have to fit 5 different model with same set of TFIDF features, so can increase our time complexity so to reduce the time complexity of the program we will use logistic regression and for binary relevance problem, we have used OneVSRestClassifier

# %%
lr = LogisticRegression()
clf = OneVsRestClassifier(lr)

# %% [markdown]
# train the model on the features 'summary train dataset and genre train dataset' and then predict the genre of book of summary test dataset.

# %%
clf.fit(Xtrain_tfidf, y_train)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=100,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=None,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False),
#                     n_jobs=None)

# %%
y_pred = clf.predict(Xtest_tfidf)

# %%
z=lb.inverse_transform(y_pred)

# %%
def genre_Pred(summary):
    sum_vec = tfidf_vector.transform([summary])
    sum_pred = clf.predict(sum_vec)
    z=lb.inverse_transform(sum_pred)
    return z

# %% [markdown]
# Next, we will predict the genere of all X_test features.

# %%
for i in range(len(X_test)): 
  k = X_test.index[i] 
  print("book: ", genre_books['title'][k], "\nPredicted genre: ", genre_Pred(X_test[k])), print("Actual genre: ",genre_books['genre'][k], "\n")
# Out:
# book:  Uncle Cleans Up
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Dear Enemy
# Predicted genre:  ['Novel']
# Actual genre:  Mystery
#
# book:  A Bend in the River
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Murder by the Book
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  What Happened to Mr. Forster?
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Rising
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Rainbow Valley
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Threat
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Children of Magic Moon
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Warbreaker
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Worst Band In The Universe
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Time for the Stars
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Toby Alone
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Bronze God of Rhodes
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Oscar and Lucinda
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Desperate Remedies
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Starlight Barking
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Return
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Appointment in Samarra
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Ellen Tebbits
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  MAX: A Maximum Ride Novel
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Annihilation
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Endymion
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Sunnydale High Yearbook
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Yume No Hon: The Book of Dreams
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Gravity's Rainbow
# Predicted genre:  ['Novel']
# Actual genre:  Science Fiction
#
# book:  Treading Air
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  A Cry in the Night
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Candle
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Ruins of Gorlan
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Kaleidoscope Century
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Dubrovsky
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Cecily Parsley's Nursery Rhymes
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Dragon's Apprentice
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Deathstalker Honour
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Edison's Conquest of Mars
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Creature of the Night
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Long Winter
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Gripping Hand
# Predicted genre:  ['Science Fiction']
# Actual genre:  Novel
#
# book:  The Anome
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Lazarus Rising
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Secret of the Forgotten City
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Room at the Top
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Shadow Dragons
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Pool of Radiance
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Good Husband of Zebra Drive
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Let the Great World Spin
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Foreign Affairs
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Lost Hero
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Eyes of Heisenberg
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Dermaphoria
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Narrative of Arthur Gordon Pym of Nantucket
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Colonization: Down to Earth
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Assemblers of Infinity
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Shadow Lord
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Saturnalia
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  A Monstrous Regiment of Women
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  And Chaos Died
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Artemis Fowl: The Eternity Code
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Destination: Void
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Midwich Cuckoos
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Silverlock
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Blue Man
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Doctor Fischer of Geneva
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Settling Accounts: The Grapple
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Dexter in the Dark
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Wishing Moon
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Salt
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Decay of the Angel
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Long Walk
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Cuckoo's Egg
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Mendoza in Hollywood
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Lock and Key
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Strange Case of Dr Jekyll and Mr Hyde
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Witches
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Fading Echoes
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Mandalorian Armor
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Emperor Mage
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Nastanirh
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Partner
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  No Telephone to Heaven
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Sky Island
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Elantris
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Keeper of the Keys
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Unexpected Guest
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Thief Lord
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Living Dead in Dallas
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Legend of Luke
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Sundering Flood
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Soccer Comes First
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
# book:  Queer
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Last Ship
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Son of the Tree
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  A Practical Man
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Idoru
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Flight of the Old Dog
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Mask
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Magic Pudding
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Inkdeath
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Curse of the Incredible Priceless Corncob
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Festival of Death
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Bedroom Secrets of the Master Chefs
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Jennie
# Predicted genre:  ['Novel']
# Actual genre:  Science Fiction
#
# book:  Hyperion
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Sam, Bangs, and Moonshine
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Quiet Earth
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  True Talents
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Visitors
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Wagon Train to the Stars
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Bro
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Prophets of the Dark Side
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Angels Flight: A Harry Bosch Novel
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Daja's Book
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Lamb: The Gospel According to Biff, Christ's Childhood Pal
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Devil in Velvet
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Six Suspects
# Predicted genre:  ['Mystery']
# Actual genre:  Novel
#
# book:  The Bourne Supremacy
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Mad God's Amulet
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Hush, Hush
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Half-Made World
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  After Dark
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Space Opera
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Journey
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Daughter of the Forest
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Warlords of Utopia
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Dead and the Gone
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Mission of Honor
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Death in the Clouds
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Long Patrol
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Ibid: A Life
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Toxin
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Still Point
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Heat
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Thinner
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  What Is To Be Done?
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Standing Dead
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Beautiful Chaos
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Ally
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Stealers of Dreams
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Seiken no Blacksmith
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Blade Runner 4: Eye and Talon
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Protector's War
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Revelation Space
# Predicted genre:  ['Science Fiction']
# Actual genre:  Fantasy
#
# book:  Icefire
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The French Powder Mystery
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  When Eight Bells Toll
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Wayside School is Falling Down
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Sun Also Rises
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The World, the Flesh, and Father Smith
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Body in the Library
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  There's a Boy in the Girls' Bathroom
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Falling Free
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Scales of the Serpent
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Reincarnation
# Predicted genre:  ['Novel']
# Actual genre:  Fantasy
#
# book:  The Descent of Anansi
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Indigo King
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Betrayal of Bindy Mackenzie
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Game Plan for Disaster
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Of Human Bondage
# Predicted genre:  ['Novel']
# Actual genre:  Childrens literature
#
# book:  The Wild Geese
# Predicted genre:  ['Novel']
# Actual genre:  Fantasy
#
# book:  Evelina
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Flinx in Flux
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Queen of Attolia
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Broken Commandment
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Waiting for the Mahatma
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Twelve Sharp
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Devlin's Luck
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Overlook
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Battle for the Park
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Flirt
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  James and the Giant Peach
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Twelve Tasks of Flavia Gemina
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Dark Secret
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Transformers: The Veiled Threat
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  More Tales of the City
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Shield of Lies
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Singing Tree
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Queen of the Damned
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Hidden Empire
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Scions of Shannara
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Lucky One
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Glasshouse
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The House of the Wolfings
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Gathering Storm
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  An Unsuitable Job for a Woman
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Thirteen Steps Down
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Shattered Peace
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Hunter's Run
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Case of the Constant Suicides
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Book of Atrix Wolfe
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Incorporated Knight
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Shatterglass
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Eternal Champion
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Greatheart Silver
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Little Engine That Could
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Boggart
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  A House Like a Lotus
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  A Burnt-Out Case
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Un Lun Dun
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The War in the Air
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Forever War
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Cat Who Talked Turkey
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The White Lioness
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Already Dead
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Death of Hope
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Rage of a Demon King
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Lion of Senet
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Heaven Shop
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Across Five Aprils
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Mississippi Jack
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Dark River
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Dew Breaker
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Jack Faust
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
# book:  Setting Free the Bears
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Rainbows End
# Predicted genre:  ['Novel']
# Actual genre:  Science Fiction
#
# book:  The Doom Brigade
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Felix Holt, the Radical
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Acts of Faith,1985
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Bridesmaid
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Atlantis Prophecy
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Settling Accounts: In at the Death
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Worry Website
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  War Game
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Castle Roogna
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Beggars in Spain
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Truth Machine
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Kindly Ones
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Doom 3: Maelstrom
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  A Spell for Chameleon
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Glory That Was
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  First Contact
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Get Shorty
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Breakheart Pass
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Gypsy in Amber
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Colonization: Aftershocks
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  A Room with a View
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Ambassador's Mission
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Artemis Fowl: The Time Paradox
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Dwellers in the Crucible
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Avalon Collection
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Beetle in the Anthill
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Boy and the Darkness
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  River of Gods
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Marianne Dreams
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Bard: The Odyssey Of the Irish
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Le père de nos pères
# Predicted genre:  ['Mystery']
# Actual genre:  Science Fiction
#
# book:  Luckypenny
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Cat Who Knew a Cardinal
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Season of the Jew
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Mezzanine: A Novel
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Sir Harold of Zodanga
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Disguise
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Illusions
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Loose Ends
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Heartstones
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  A Flame in Hali
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  1982, Janine
# Predicted genre:  ['Novel']
# Actual genre:  Fantasy
#
# book:  Battledragon
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Chroniques du Pays des Mères
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  All She Was Worth
# Predicted genre:  ['Novel']
# Actual genre:  Mystery
#
# book:  Love, Aubrey
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Blunderer
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  La Maravilla
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Zuckerman Unbound
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Back Roads
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Out from Boneville
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Memory Keeper's Daughter
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  A Fire in the Sun
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Predator's Gold
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Highway Men
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Star Wars Republic Commando: True Colors
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Greek Who Stole Christmas
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Advise and Consent: A Novel of Washington Politics
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Just Ella
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Story of B
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Terrier
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Friday
# Predicted genre:  ['Science Fiction']
# Actual genre:  Novel
#
# book:  Fear of the Dark
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Limitations
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  A Meeting at Corvallis
# Predicted genre:  ['Fantasy']
# Actual genre:  Science Fiction
#
# book:  The City of Ravens
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Sabre-Tooth
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Curious George Rides a Bike
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Coffin Quilt
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  We're Back! A Dinosaur's Story
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Professor's House
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Empire
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Monster Bed
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Faith of the Fallen
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Absolutely Normal Chaos
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Magicians' Guild
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Killing Floor
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Saving Fish from Drowning
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  CHERUB: The Fall
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Echo
# Predicted genre:  ['Novel']
# Actual genre:  Fantasy
#
# book:  Bloodline
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Gilead
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Methuselah's Children
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The King Beyond the Gate
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Vineland
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Eight Days of Luke
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Goggle-Eyes
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  River of Smoke
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Kermit the Hermit
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Tango on intohimoni
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Shape of Water
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Changeling
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Budding Prospects
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Joy
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Crescendo
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Hallucinating Foucault
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Wyst: Alastor 1716
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Agent 13: The Serpentine Assassin
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Gardens of the Moon
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Fallen
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Anastasia At Your Service
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Stranger
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Living and the Dead
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Centurion's Empire
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Interesting Times
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Brown Girl in the Ring
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Sandbar Sinister
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Garden of Rama
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Cat Who Could Read Backwards
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Lost City of Faar
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Book of Opposites
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Death Cure
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Penderwicks: A Summer Tale of Four Sisters, Two Rabbits, and a Very Interesting Boy
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Psycho House
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Freak the Mighty
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Spellfire
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Chapterhouse Dune
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Wind Boy
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Golden Road
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Rosetta
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Shadow of the Hegemon
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Let the Circle Be Unbroken
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Magic Goes Away
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Charlie Chan Carries On
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Player of Games
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Sideways
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Atlas Shrugged
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Babylon 5: Legions of Fire - Armies of Light and Dark
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Pot-Bouille
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Jonathan Strange & Mr Norrell
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
# book:  Waiting for The Rain
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Macdermots of Ballycloran
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Operation Thunder Child
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Magellanic Cloud
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Big Planet
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Daniel X: Watch the Skies
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Sail
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Grotesque
# Predicted genre:  ['Novel']
# Actual genre:  Mystery
#
# book:  Sense and Sensibility
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Moderato Cantabile
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Until the Celebration
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Fire Within
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Little Green Men: A Novel
# Predicted genre:  ['Science Fiction']
# Actual genre:  Mystery
#
# book:  The Clocks
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Vampirates: Blood Captain
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Lost in a Good Book
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Dragonflight
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Queen Ann in Oz
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Debt of Bones
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Fight Club
# Predicted genre:  ['Novel']
# Actual genre:  Mystery
#
# book:  The Sword Thief
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Stolen
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Dreadful Sanctuary
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Dragongirl
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Secret House of Death
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Time and Mr. Bass
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Protector
# Predicted genre:  ['Science Fiction']
# Actual genre:  Novel
#
# book:  The Secrets of Jin-Shei
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Planet of the Apes
# Predicted genre:  ['Science Fiction']
# Actual genre:  Fantasy
#
# book:  Bao Gong An
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Gods Themselves
# Predicted genre:  ['Science Fiction']
# Actual genre:  Fantasy
#
# book:  The Master Mind of Mars
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Hunters of Dune
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  No Longer at Ease
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Mausoleum Murder
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Eternal Curse on the Reader of These Pages
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Don't Forget the Bacon!
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Around the Moon
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Eva
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Jack, the Giant Killer
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Deathstalker
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  A Fine and Private Place
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Niels Klim's Underground Travels
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Crusader
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Last Canadian
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Blasphemy
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Shiva Option
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Both Sides of Time
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  He, She and It
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Seventh Son
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Lad and the Lion
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  After the Bomb
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Double Fudge
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Be More Chill
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Wide Window
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Digging Leviathan
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Wolf Worlds
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  A Talent for War
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Enna Burning
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Long Lost
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Knowledge of Angels
# Predicted genre:  ['Fantasy']
# Actual genre:  Mystery
#
# book:  The Cricket in Times Square
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Danny Dunn, Invisible Boy
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Backwards
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Wednesday Wars
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Rowan
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Resistance: The Gathering Storm
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Briar Rose
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Whipping Boy
# Predicted genre:  ['Fantasy']
# Actual genre:  Childrens literature
#
# book:  The Liar
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Begum's Millions
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Go
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Ghosts
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Frisk
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Mass Effect: Retribution
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Pellucidar
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Dark Secret of Weatherend
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Dressmaker
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  I am a Dalek
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Beach Music
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Fire in the Mist
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Sleeping Beauty: A Lew Archer Novel
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Unusual Suspects
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Iron Man
# Predicted genre:  ['Science Fiction']
# Actual genre:  Fantasy
#
# book:  That Was Then, This Is Now
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Seeds of Life
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Assassins
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  She Lover of Death
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Space Viking
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Triton
# Predicted genre:  ['Novel']
# Actual genre:  Science Fiction
#
# book:  Twisted
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
# book:  The Adventures of Super Diaper Baby
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Skin Tight
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Fire on the Mountain
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Dragons of Babel
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Bungalow 2
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Postcards from the Edge
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  All You Need Is Kill
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Ballad of Beta-2
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Santaroga Barrier
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Roar
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Bastard Prince
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Door in the Lake
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Starfighters of Adumar
# Predicted genre:  ['Science Fiction']
# Actual genre:  Fantasy
#
# book:  The Wonderful Flight to the Mushroom Planet
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Mocking Program
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Gobbolino, the Witch's Cat
# Predicted genre:  ['Fantasy']
# Actual genre:  Childrens literature
#
# book:  Fletch
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Marianne and Mark
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Killings at Badger's Drift
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Magical Monarch of Mo
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Missee Lee
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  A Fairly Honourable Defeat
# Predicted genre:  ['Fantasy']
# Actual genre:  Novel
#
# book:  Bee Season: A Novel
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Silent Speaker
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Ascending
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Reliquary
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Danish Girl
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Romance of Atlantis
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Janissaries
# Predicted genre:  ['Science Fiction']
# Actual genre:  Fantasy
#
# book:  The Ersatz Elevator
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Keeper
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Name of this Book is Secret
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Witch and Wizard: The Gift
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Fear Nothing
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Werewolf versus Dragon
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Mariel of Redwall
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Double Whammy
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Endangered Species
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Tin Roof Blowdown: A Dave Robicheaux Novel
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Faceless Killers: A Mystery
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Empire of Ivory
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Alchemist
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Le lion
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Irish Crystal
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Dragon Society
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Absent in the Spring
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Chinese Lake Murders
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Weaver
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Subtle Knife
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Declaration
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Owl Moon
# Predicted genre:  ['Novel']
# Actual genre:  Childrens literature
#
# book:  Great Kings' War
# Predicted genre:  ['Fantasy']
# Actual genre:  Science Fiction
#
# book:  The Pillars of Creation
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Outbreak
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Acts of God
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Little Eva: The Flower of the South
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Last Shot
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Passenger to Frankfurt
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Briar King
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Al Capone Does My Shirts
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Power that Preserves
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Man Plus
# Predicted genre:  ['Science Fiction']
# Actual genre:  Novel
#
# book:  Caddie Woodlawn
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Justin Morgan Had a Horse
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Wandering Fire
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Maintenance of Headway
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Whose Body?
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Drop to His Death
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Summer Tree
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Runes of the Earth
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Grizzly
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Landry News
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Last Dog on Earth
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Patterns of Force
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  In the Path of the Storm
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Pippi Longstocking
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Rebecca of Sunnybrook Farm
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The King's Peace
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Hitman: Enemy Within
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Leaky Establishment
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  First Boy
# Predicted genre:  ['Childrens literature']
# ...
#
# book:  Undead and Unwelcome
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Adventures of Captain Underpants
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  In the Time of the Butterflies
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Blooded
# Predicted genre:  ['Fantasy']
# Actual genre:  Mystery
#
# book:  In the Grip of Winter
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Generation Dead
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Strange World of Planet X
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Temple of the Ten
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Kachina Doll Mystery
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The House with a Clock in Its Walls
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  My Gun Is Quick
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Born of the Storm
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Honor of the Queen
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Book of Ultimate Truths
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Road of Kings
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The World in the Evening
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Last Man
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Simon and the Witch
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Home Truths: A Novella
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Doon
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Dragon Ultimate
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Acacia: The War With The Mein
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Watsons
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  End time
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Bold as Love
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Tropic of Cancer
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Tanis, the Shadow Years
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Gone-Away World
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Falcons of Narabedla
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Jewels of Aptor
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Futurological Congress
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Les Misérables
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Dragons of the Highlord Skies
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
# book:  The Lamp Of God
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Dune: House Corrino
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The moon riders
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The White Hart
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Higher Education
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Irish Love
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Jarka Ruus
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Delivery Man
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Forever King
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Rumours of Rain
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Brothers Majere
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Brendon Chase
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Sense of the Past
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Tomorrow People
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Pichilemu Blues
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Finding Cassie Crazy
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Book of Skulls
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  In the Days of the Comet
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Firestarter
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Problem of the Wire Cage
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  David Copperfield
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Cinder
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  By the Shores of Silver Lake
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Lightning
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Portrait of Lozana: The Lusty Andalusian Woman
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Finnikin of the Rock
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Swords of Lankhmar
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Tony Hale, Space Detective
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Code of the Woosters
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Platoon Leader
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Third Twin
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Wolf to the Slaughter
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Halo: Contact Harvest
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Devil's Company
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Time Zero
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  High Deryni
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  A Princess of Mars
# Predicted genre:  ['Science Fiction']
# Actual genre:  Fantasy
#
# book:  Cue for Treason
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Voyage to the City of the Dead
# Predicted genre:  ['Science Fiction']
# Actual genre:  Fantasy
#
# book:  Abarat
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Joke
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Enemy
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Night of Light
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Operation Chaos
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Les Enfants Terribles
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Custom of the Army
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Children of the Jedi
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Forty Signs of Rain
# Predicted genre:  ['Novel']
# Actual genre:  Science Fiction
#
# book:  On Beauty
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Forest House
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Last Man Standing
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Saint Steps In
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Lucky You
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Book of Ptath
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Revolt on Alpha C
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Austere Academy
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Black Water
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Chasing Vermeer
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Masks of Time
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  The Borrowers
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Hills End
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  A Christmas Carol
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Vanished Man
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Yearling
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Devdas
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Vampire Hunter D Volume 1
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Isaac Asimov's Caliban
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Redemption of Althalus
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Phantom of the Temple
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  There Are Doors
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Long Goodbye
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Velocity
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Mistborn: The Alloy of Law
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Haunted Woman
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  No place like home
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Year of Our War
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Along Came a Spider
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Five Chinese Brothers
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  High Fidelity
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Masters of Darkness
# Predicted genre:  ['Fantasy']
# Actual genre:  Childrens literature
#
# book:  If You Could See Me Now
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Magician's Apprentice
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Fatal Equilibrium
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Cirie
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Johnny and the Bomb
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Who?
# Predicted genre:  ['Novel']
# Actual genre:  Science Fiction
#
# book:  The Dying Animal
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Norstrilia
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Military Philosophers
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  City of Pearl
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Of the City of the Saved...
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  In the Hand of Dante
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Schild's Ladder
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Expiration Date
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Farming of Bones
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Monsieur
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Poe Shadow
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Wednesday's Child
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  The Bird of Time
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Jubilee
# Predicted genre:  ['Novel']
# Actual genre:  Childrens literature
#
# book:  The Chinese Bell Murders
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  The Entropy Effect
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Return from the Stars
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Second Angel
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Watchers
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  The Grass Harp
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Track of the Zombie
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Ilium/Olympus
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Heaven Eyes
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Laughter in the Dark
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  The Stronghold
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  A Great and Terrible Beauty
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Notes from Underground
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Assassin's Quest
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Born to Exile
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Hitty, Her First Hundred Years
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Speak
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Caballero: A Historical Novel
# Predicted genre:  ['Novel']
# Actual genre:  Novel
#
# book:  Monolith
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Lee's Holiday Showdown
# Predicted genre:  ['Childrens literature']
# Actual genre:  Childrens literature
#
# book:  Dark Calling
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  NP
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Alice in Verse: The Lost Rhymes of Wonderland
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Trapped At Sea
# Predicted genre:  ['Childrens literature']
# Actual genre:  Mystery
#
# book:  Conan the Freebooter
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  The Voyage of the Space Beagle
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  Deeds of the Disturber
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery
#
# book:  Antrax
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Wing Commander: False Colors
# Predicted genre:  ['Science Fiction']
# Actual genre:  Science Fiction
#
# book:  The Difference Engine
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  The Black Prism
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
# book:  The Black Company
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Dawn
# Predicted genre:  ['Childrens literature']
# Actual genre:  Science Fiction
#
# book:  Half a Team
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Son of a Witch
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Dread Mountain
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  Ourika
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  The Eye of the Heron
# Predicted genre:  ['Childrens literature']
# Actual genre:  Fantasy
#
# book:  Falling
# Predicted genre:  ['Childrens literature']
# Actual genre:  Novel
#
# book:  Night season
# Predicted genre:  ['Fantasy']
# Actual genre:  Fantasy
#
# book:  A Murder of Quality
# Predicted genre:  ['Mystery']
# Actual genre:  Mystery

# %%
#Calculating accuracy score of the test and train data model
y_pred_train=clf.predict(Xtrain_tfidf);
y_pred_test=clf.predict(Xtest_tfidf);

y_train_accscore=accuracy_score(y_train,y_pred_train);
y_test_accscore=accuracy_score(y_test,y_pred_test);

print('TrainDataSet accuracy score:',y_train_accscore)
print('TestDataset accuracy score:',y_test_accscore)
# Out:
# TrainDataSet accuracy score: 0.5213700670141475
# TestDataset accuracy score: 0.4037516748548459

# %% [markdown]
# So, the accuracy score of test and train dataset are 52 and 40 percent, which tell us that this model can predict the genre tag
# of the data.It is not very high accuracy but it is not very low accuracy as the baseline accuracy for each target genre is 20 percent and we have crossed that baseline, so our model can used in predicting the genre.
